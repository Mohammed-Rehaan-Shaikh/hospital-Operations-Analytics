# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\IDE\Projects\hospital-Operations-Analytics\Data\healthcare_analytics_patient_flow_data.csv")

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.head()
# Out:
#     patient_id patient_admission_date patient_admission_time  patient_name  \
# 0  780-96-6113               9/9/2024             9:25:00 AM     W. Breede
# 1  714-35-6722               9/9/2024             4:42:00 PM   Y. Baldetti
# 2  571-85-3714               9/9/2024            12:14:00 AM    M. Semerad
# 3  404-43-9499               9/9/2024             8:33:00 PM    K. Blaydes
# 4  552-51-5855               9/9/2024             7:25:00 PM  F. Dickerson
#
#   patient_gender  patient_age      patient_race department_referral  \
# 0         Female           63  African American                 NaN
# 1           Male           31             Asian         Orthopedics
# 2           Male           75             White    General Practice
# 3           Male           79  African American    General Practice
# 4         Female           24  African American                 NaN
#
#   patient_admission_flag  patient_satisfaction_score  patient_waittime
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9216 entries, 0 to 9215
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   patient_id                  9216 non-null   str
#  1   patient_admission_date      9216 non-null   str
#  2   patient_admission_time      9216 non-null   str
#  3   patient_name                9216 non-null   str
#  4   patient_gender              9216 non-null   str
#  5   patient_age                 9216 non-null   int64
#  6   patient_race                9216 non-null   str
#  7   department_referral         3816 non-null   str
#  8   patient_admission_flag      9216 non-null   str
#  9   patient_satisfaction_score  2517 non-null   float64
#  10  patient_waittime            9216 non-null   int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 792.1 KB

# %%
df.isnull().sum()
# Out:
# patient_id                       0
# patient_admission_date           0
# patient_admission_time           0
# patient_name                     0
# patient_gender                   0
# patient_age                      0
# patient_race                     0
# department_referral           5400
# patient_admission_flag           0
# patient_satisfaction_score    6699
# patient_waittime                 0
# dtype: int64

# %%
df["patient_gender"].unique()
# Out:
# <StringArray>
# ['Female', 'Male', 'Femaleemale']
# Length: 3, dtype: str

# %%
#Fix incorrect gender value
df["patient_gender"] = df["patient_gender"].replace(
    "femaleemale",
    "Unknown"
)

# %%
df["department_referral"].unique()
# Out:
# <StringArray>
# [               nan,      'Orthopedics', 'General Practice',
#     'Physiotherapy',            'Renal', 'Gastroenterology',
#        'Cardiology',        'Neurology']
# Length: 8, dtype: str

# %%
# Replace nan department values
df["department_referral"] = (
    df["department_referral"]
    .replace("", "Not Specified")
    .fillna("Not Specified")
)

# %%
#To verify whether the nan value were replaced or not
df.isnull().sum()
# Out:
# patient_id                       0
# patient_admission_date           0
# patient_admission_time           0
# patient_name                     0
# patient_gender                   0
# patient_age                      0
# patient_race                     0
# department_referral              0
# patient_admission_flag           0
# patient_satisfaction_score    6699
# patient_waittime                 0
# dtype: int64

# %%
df.to_csv(r"C:\IDE\Projects\hospital-Operations-Analytics\Data\cleaned_patient_data.csv", index=False)
